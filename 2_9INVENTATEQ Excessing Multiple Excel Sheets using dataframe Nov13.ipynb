# %%
import numpy as np
import pandas as pd

# %%
excel_file = pd.read_excel('C:\\Users\\Parul\\Desktop\\DATASETS\\AmazingMartEU2.xlsx','ListOfOrders',index=['Order ID'])
excel_file2 = pd.read_excel('C:\\Users\\Parul\\Desktop\\DATASETS\\AmazingMartEU2.xlsx','OrderBreakdown',index=['Order ID'])
excel_file.join(excel_file2, how='inner',lsuffix='Order ID1', rsuffix='Order ID2')
# Out:
#      Order IDOrder ID1 Order Date        Customer Name                 City  \
# 0      BN-2011-7407039 2011-01-01           Ruby Patel            Stockholm
# 1      AZ-2011-9050313 2011-01-03       Summer Hayward            Southport
# 2      AZ-2011-6674300 2011-01-04     Devin Huddleston              Valence
# 3      BN-2011-2819714 2011-01-04          Mary Parker           Birmingham
# 4       AZ-2011-617423 2011-01-05         Daniel Burke           Echirolles
# 5      AZ-2011-2918397 2011-01-07   Fredrick Beveridge     La Seyne-sur-Mer
# 6      BN-2011-3248724 2011-01-08          Archer Hort             Toulouse
# 7      AZ-2011-6712797 2011-01-11       Evie Flockhart                Genoa
# 8      AZ-2011-4827146 2011-01-11      Faith Greenwood               Vienna
# 9      AZ-2011-6439906 2011-01-11       Summer Hayward               Murcia
# 10     AZ-2011-7053593 2011-01-11        Gracie Powell               Woking
# ...

# %%
excel_file
# Out:
#              Order ID Order Date        Customer Name                 City  \
# 0     BN-2011-7407039 2011-01-01           Ruby Patel            Stockholm
# 1     AZ-2011-9050313 2011-01-03       Summer Hayward            Southport
# 2     AZ-2011-6674300 2011-01-04     Devin Huddleston              Valence
# 3     BN-2011-2819714 2011-01-04          Mary Parker           Birmingham
# 4      AZ-2011-617423 2011-01-05         Daniel Burke           Echirolles
# 5     AZ-2011-2918397 2011-01-07   Fredrick Beveridge     La Seyne-sur-Mer
# 6     BN-2011-3248724 2011-01-08          Archer Hort             Toulouse
# 7     AZ-2011-6712797 2011-01-11       Evie Flockhart                Genoa
# 8     AZ-2011-4827146 2011-01-11      Faith Greenwood               Vienna
# 9     AZ-2011-6439906 2011-01-11       Summer Hayward               Murcia
# 10    AZ-2011-7053593 2011-01-11        Gracie Powell               Woking
# ...

# %%
excel_file2
# Out:
#              Order ID                                       Product Name  \
# 0     BN-2011-7407039                        Enermax Note Cards, Premium
# 1     AZ-2011-9050313                 Dania Corner Shelving, Traditional
# 2     AZ-2011-6674300              Binney & Smith Sketch Pad, Easy-Erase
# 3     BN-2011-2819714                         Boston Markers, Easy-Erase
# 4     BN-2011-2819714                        Eldon Folders, Single Width
# 5      AZ-2011-617423       Binney & Smith Pencil Sharpener, Water Color
# 6      AZ-2011-617423                        Sanford Canvas, Fluorescent
# 7     AZ-2011-2918397                      Bush Floating Shelf Set, Pine
# 8     AZ-2011-2918397                  Accos Thumb Tacks, Assorted Sizes
# 9     AZ-2011-2918397                          Smead Lockers, Industrial
# 10    BN-2011-3248724                       Ikea Classic Bookcase, Metal
# 11    BN-2011-3248724                    Binney & Smith Sketch Pad, Blue
# ...

# %%
excel_file.index
# Out:
# RangeIndex(start=0, stop=4117, step=1)

# %%
excel_file2.index
# Out:
# RangeIndex(start=0, stop=8047, step=1)

# %%
pd.merge(df,df1, how='left')
# Out:
#              Order ID Order Date        Customer Name              City  \
# 0     BN-2011-7407039 2011-01-01           Ruby Patel         Stockholm
# 1     AZ-2011-9050313 2011-01-03       Summer Hayward         Southport
# 2     AZ-2011-6674300 2011-01-04     Devin Huddleston           Valence
# 3     BN-2011-2819714 2011-01-04          Mary Parker        Birmingham
# 4     BN-2011-2819714 2011-01-04          Mary Parker        Birmingham
# 5      AZ-2011-617423 2011-01-05         Daniel Burke        Echirolles
# 6      AZ-2011-617423 2011-01-05         Daniel Burke        Echirolles
# 7     AZ-2011-2918397 2011-01-07   Fredrick Beveridge  La Seyne-sur-Mer
# 8     AZ-2011-2918397 2011-01-07   Fredrick Beveridge  La Seyne-sur-Mer
# 9     AZ-2011-2918397 2011-01-07   Fredrick Beveridge  La Seyne-sur-Mer
# 10    BN-2011-3248724 2011-01-08          Archer Hort          Toulouse
# 11    BN-2011-3248724 2011-01-08          Archer Hort          Toulouse
# ...

# %%
pd.merge(df,df1, how= 'outer')

# %%
pd.merge(df,df1, how= 'right')

# %%
y = x[['Order ID','Order Date','Customer Name','Product Name','City','Country','Region','Segment','Ship Date','Ship Mode' ]]
y
